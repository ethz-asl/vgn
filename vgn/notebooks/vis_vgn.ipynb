# %% [markdown]
# Notebook to visualize the grasping network output.

# %%
weights = ""
scene = "/home/michel/catkin_ws/src/grasp_playground/vgn/data/datasets/cuboid_random/0aa8c96040404bce8cea775d9b6a55b8"
