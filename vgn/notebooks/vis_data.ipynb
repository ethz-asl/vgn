# %% [markdown]
# Notebook to visualize samples from the generated grasp dataset.

# %%
import argparse
import os

import numpy as np
import open3d
from mayavi import mlab

from vgn.dataset import VGNDataset
from vgn.utils import vis

# %%
scene = "/home/michel/catkin_ws/src/grasp_playground/vgn/data/datasets/cuboid/00a1519a9dde43c0b8ad3e149b6cee23"

# Load dataset
dataset= VGNDataset(os.path.dirname(scene))
index = dataset.scenes.index(os.path.basename(scene))

tsdf, indices, quats, outcomes = dataset[index]
quats = np.swapaxes(quats, 0, 1)

# Visualize TSDF
mlab.figure()
vis.draw_voxels(tsdf)
vis.draw_candidates(indices, quats, scores, draw_frames=True)
mlab.show()
# Out:
# 0%|          | 0/1000 [00:00<?, ?it/s]Verifying cache:
# NameErrorTraceback (most recent call last)
# <ipython-input-5-0eae524149ff> in <module>()
#       2
#       3 # Load dataset
# ----> 4 dataset= VGNDataset(os.path.dirname(scene))
#       5 index = dataset.scenes.index(os.path.basename(scene))
#       6
#
# /home/michel/catkin_ws/src/grasp_playground/vgn/src/vgn/dataset.py in __init__(self, root_dir, rebuild_cache)
#      28
#      29         self.detect_scenes()
# ---> 30         self.build_cache()
#      31
#      32     def __len__(self):
#
# /home/michel/catkin_ws/src/grasp_playground/vgn/src/vgn/dataset.py in build_cache(self)
#      60             path = os.path.join(self.cache_dir, dirname) + ".npz"
#      61             if not os.path.exists(path) or self.rebuild_cache:
# ---> 62                 scene = data.load_scene(os.path.join(self.root_dir, dirname))
#      63                 _, voxel_grid = data.reconstruct_volume(scene)
#      64                 tsdf = utils.voxel_grid_to_array(voxel_grid, cfg.resolution)
#
# /home/michel/catkin_ws/src/grasp_playground/vgn/src/vgn/utils/data.pyc in load_scene(dirname)
#      13     intrinsic = _load_intrinsic(dirname)
#      14     extrinsics, images = _load_images(dirname)
# ---> 15     poses, outcomes = _load_grasps(dirname)
#      16     scene = {
#      17         "intrinsic": intrinsic,
#
# /home/michel/catkin_ws/src/grasp_playground/vgn/src/vgn/utils/data.pyc in _load_grasps(dirname)
#      69     for i, grasp in enumerate(grasps):
#      70         poses.append(Transform.from_dict(grasp["pose"]))
# ---> 71         outcome[i] = grasp["outcome"]
#      72     return poses, outcomes
#      73
#
# NameError: global name 'outcome' is not defined
